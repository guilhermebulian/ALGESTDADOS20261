# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermebulian/ALGESTDADOS20261/blob/main/Teste/26_fev_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!
