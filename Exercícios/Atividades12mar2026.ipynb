# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermebulian/ALGESTDADOS20261/blob/main/Exerc%C3%ADcios/Atividades12mar2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01 - Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.
a = 15
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
# 02 - Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra:
# quantos grupos completos serão formados?
print(f'Podem ser formados {37//5} grupos completos.')

# quantos alunos sobrarão?
print(f'Sobrarão {37 % 5} alunos')
# Out:
# Podem ser formados 7 grupos completos.
# Sobrarão 2 alunos

# %%
# 03 - Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem:
base = 8.5
altura = 3.2
print(f'A área do retângulo é: {base*altura:.2f}')
# Out:
# A área do retângulo é: 27.20

# %%
# 04 - Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída:
segundos = 9875
minutos = segundos//60
segundos = segundos%60
horas = minutos//60
minutos = minutos%60
print(f'{horas}h {minutos}min e {segundos}s')
# Out:
# 2h 44min e 35s

# %%
# 05 - Calcule:
2**10
#R: Essa operação representa que 2 está elevado a sua décima potência

# Explique com um comentário no código o que essa operação representa. Depois calcule a raiz quadrada de 144 usando potenciação.
print(f'A raiz de 144 é {144**(1/2)}')
# Out:
# A raiz de 144 é 12.0

# %%
# 06 - Crie uma variável:
temperatura = 38.5

#Use operadores relacionais para verificar:
print(temperatura>37.5)
print(temperatura==36.5)
print(temperatura!=40)
# Out:
# True
# False
# True

# %%
# 07 - Dados:
x = 10
y = 10

# Preveja o resultado antes de executar e depois confirme no Python:
print(x == y) #True
print(x != y) #False
print(x >= y) #True
print(x <= y + 1) #True
# Out:
# True
# False
# True
# True

# %%
# 08 - Um aluno tirou nota 6.5. Usando operadores relacionais, verifique se ele:
nota = 6.5
print(f' Tirei {nota}. Fui aprovado? {nota>=7.0}')
print(f' Tirei {nota}. Estou de recuperação? {nota>=5.0 and nota<7.0}')
print(f' Tirei {nota}. Eu fui reprovado? {nota<5.0}')
# Out:
#  Tirei 6.5. Fui aprovado? False
#  Tirei 6.5. Estou de recuperação? True
#  Tirei 6.5. Eu fui reprovado? False

# %%
# 09 - Declare:
a = 5
b = "5"
a == b
print(f'A relação de igualdade entre a ({a}) e b ({b}) é {a == b}')
# Out:
# A relação entre a (5) e b (5) é False

# %%
# 10 - Crie um programa com:
preço = 49.90
orçamento = 50.00

# Verifique se o produto está dentro do orçamento de R$ 50,00 usando <=.
print(f'Tenho R${orçamento}, e o preço do produto é R${preço}. O produto está dentro do orçamento? {preço<=orçamento}')
# Out:
# Tenho R$50.0, e o preço do produto é R$49.9. O produto está dentro do orçamento? True

# %%
# 11 - ma pessoa pode votar se tiver 16 anos ou mais.
idade = 15
print(f'Tenho {idade} anos. Essa pessoa pode votar: {idade>=16}')
# Use operadores lógicos para verificar se ela não pode votar. Depois teste com:
idade = 18
print(f'Tenho {idade} anos. Essa pessoa pode votar: {idade>=16}')
# Out:
# Essa pessoa pode votar: False
# Essa pessoa pode votar: True

# %%
# 12 - Teste pelo menos três combinações diferentes usando and.
#A)
renda = 1500
score = 650
print(f'Minha renda é {renda} e meu score é {score}. O empréstimo foi aprovado? {renda>=2000 and score>=700}')
#B)
renda = 4200
score = 200
print(f'Minha renda é {renda} e meu score é {score}. O empréstimo foi aprovado? {renda>=2000 and score>=700}')
#C)
renda = 2500
score = 750
print(f'Minha renda é {renda} e meu score é {score}. O empréstimo foi aprovado? {renda>=2000 and score>=700}')
# Out:
# Minha renda é 1500 e meu score é 650. O empréstimo foi aprovado? False
# Minha renda é 4200 e meu score é 200. O empréstimo foi aprovado? False
# Minha renda é 2500 e meu score é 750. O empréstimo foi aprovado? True

# %%
# 13 - Um sistema libera acesso se o usuário for administrador ou tiver nível de acesso ≥ 3.
is_admin = False
nivel_acesso = 4
print(f'Liberar acesso: {is_admin or nivel_acesso>=3}')
# Out:
# Liberar acesso: True

# %%
# 14 - Dado:
# Use not para verificar se não está chovendo. Depois combine com uma verificação de temperatura maior que 25.
chovendo = True
temperatura = 26
print(f'Está chovendo? {not chovendo} \nTemperatura é maior do que 25ºC? {temperatura>25}')
# Out:
# Está chovendo? False
# Temperatura é maior do que 25ºC? True

# %%
#15 - Monte manualmente a tabela-verdade do operador
print('Tabela-verdade do operador AND')
print(' A            B            C')
print(f'True   and   True    =   {True and True}')
print(f'True   and   False   =   {True and False}')
print(f'False  and   True    =   {False and True}')
print(f'False  and   False   =   {False and False}')
# Out:
# Tabela-verdade do operador AND
#  A            B            C
# True   and   True    =   True
# True   and   False   =   False
# False  and   True    =   False
# False  and   False   =   False

# %%
#16 - Calcule manualmente antes de executar:
5 + 2 * 3 #R: 30, pois primeiro é feito o produto de 2*3 e a resultante é somada com 5.

(5 + 2) * 3 #R: 21, pois primeiro é resolvido a soma de 5+2 dentro do parênteses, multiplicando o resultado por 3.

2 ** 3 ** 2 #R: 512, pois o 3 é elevado a segunda potência para seu resultado ser utilizado na potência de 2.

10 - 4 / 2 + 1 #R: 9, pois a divisão é feita primeiro, o 10 é subtraído pelo resultado e após isso soma-se com 1.

# %%
#17 - Resolva passo a passo:
resultado = 3 + 2 * 4 ** 2 - 1
#1º passo > 4 * 2 = 16, ou seja, resultado = 3 + 2 * 16 - 1
#2º passo > 16 * 2 = 32 ou seja, resultado = 3 + 32 - 1
#3º passo > 3 + 32 - 1 = 34 ou seja, resultado = 34
print(resultado)

#Reescreva usando parênteses para mostrar a ordem das operações.
resultado = 3 + (2 * (4 ** 2)) - 1
# Out:
# 34

# %%
# 18 - Analise o resultado da expressão abaixo antes de executar:
x = 4 + 3 * 2 > 9 and not (5 == 5)

# %%
# 19 -  Reescreva usando parênteses para obter os resultados indicados:
a = 10 / (2 + 3)
print(a)

b = not (True or False)
print(b)
# Out:
# 2.0
# False

# %%
# 20 - Crie uma expressão que use operadores aritméticos, relacionais e lógicos para resolver o problema:
# Um estudante é aprovado com distinção se a média de duas notas for maior ou igual a 9.0 e nenhuma das notas for menor que 7.0.
nota = 9.5
nota2 = 8.5
media = (nota + nota2) / 2
print(f'Está Aprovado? {media>=9 and nota>=7 and nota2>=7}')
# Out:
# Está Aprovado? True
